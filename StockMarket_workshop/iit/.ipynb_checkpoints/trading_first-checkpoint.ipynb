# %%
# Imports
import pandas as pd
import talib as ta
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# /home/hitul/.pyenv/versions/3.6.3/envs/iit/lib/python3.6/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /home/hitul/.pyenv/versions/3.6.3/envs/iit/lib/python3.6/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# #### Download trading data

# %% [markdown]
# #### Load data

# %%
df = pd.read_csv('yesbank.csv', index_col='Date')
df.keys()
df
# Out:
#               Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 01-Jan-2019  YESBANK     EQ      181.80      182.60      185.90     181.00
# 02-Jan-2019  YESBANK     EQ      184.25      183.45      187.00     182.50
# 03-Jan-2019  YESBANK     EQ      184.65      185.25      186.00     183.50
# 04-Jan-2019  YESBANK     EQ      184.10      184.85      190.30     181.55
# 07-Jan-2019  YESBANK     EQ      189.65      193.90      194.40     185.80
# ...              ...    ...         ...         ...         ...        ...
# 26-Sep-2019  YESBANK     EQ       53.70       53.90       54.25      50.55
# 27-Sep-2019  YESBANK     EQ       51.05       50.00       52.90      48.40
# 30-Sep-2019  YESBANK     EQ       48.75       48.25       49.10      40.95
# 01-Oct-2019  YESBANK     EQ       41.40       42.00       44.30      29.00
# 03-Oct-2019  YESBANK     EQ       32.00       35.20       43.45      35.20
#
# ...

# %% [markdown]
# ##### Line ploting of closing price

# %%
df[['Close Price']].plot(figsize=(15,10))

# %%
df['Close Price SMA 30'] = ta.SMA(df['Close Price'])
df['Close Price SMA 20'] = ta.SMA(df['Close Price'], timeperiod=20)
df['Close Price SMA 10'] = ta.SMA(df['Close Price'], timeperiod=10)
df['Close Price SMA 5'] = ta.SMA(df['Close Price'], timeperiod=5)

# %%
df[['Low Price SMA 5', 'Low Price']].plot(
    figsize=(15,10),
    grid=True,
    legend=True
)

# %% [markdown]
# #### Calculate Low price EMA and WMA

# %%
df['Low Price EMA 30'] = ta.EMA(df['Low Price'])
df['Low Price EMA 20'] = ta.EMA(df['Low Price'], timeperiod=20)
df['Low Price EMA 10'] = ta.EMA(df['Low Price'], timeperiod=10)
df['Low Price EMA 5'] = ta.EMA(df['Low Price'], timeperiod=5)

# %%
df['Low Price WMA 30'] = ta.WMA(df['Low Price'])
df['Low Price WMA 20'] = ta.WMA(df['Low Price'], timeperiod=20)
df['Low Price WMA 10'] = ta.WMA(df['Low Price'], timeperiod=10)
df['Low Price WMA 5'] = ta.WMA(df['Low Price'], timeperiod=5)

# %%
df[['Low Price WMA 10', 'Low Price SMA 10', 'Low Price EMA 10', 'Low Price']].plot(
    figsize=(15,10),
    grid=True, 
    legend=True
)
